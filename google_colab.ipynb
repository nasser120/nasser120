# %% [markdown]
# <a href="https://colab.research.google.com/github/nasser120/nasser120/blob/dheemanluula/google_colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # this *is* **heading**

# %% [markdown]
# ```
# # This is formatted as code
# for item list:
# print(iten)
# ```

# %% [markdown]
# ![WhatsApp Image 2024-10-12 at 21.08.13_9dadbc56.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# [google search](https://www.google.com)

# %% [markdown]
# 1.   first
# 2.   second
#
# xbxhbsxv
#
# > bvcvcv
#
#
# gfsfasfsacyg

# %% [markdown]
# hello

# %% [markdown]
# $ a*x^2+c=0 $

# %% [markdown]
# x1=/frac{a-b /sqrt}{b-d}
